# %%
# PySpark Concepts Learning Notebook
'''
This notebook covers core PySpark concepts with runnable examples:
- SparkSession & DataFrame basics
- Schemas & reading data
- Transformations vs Actions & lazy evaluation
- Column functions & expressions
- Joins & broadcast joins
- Window functions
- Aggregations & groupBy
- UDFs and pandas UDFs
- Partitioning, repartition, coalesce
- Caching / persistence
- Shuffle, skew, and performance tips
- Debugging & explain plan

Run cells one-by-one. Each code cell is self-contained and prints results. Small datasets used for clarity.
'''
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# '\nThis notebook covers core PySpark concepts with runnable examples:\n- SparkSession & DataFrame basics\n- Schemas & reading data\n- Transformations vs Actions & lazy evaluation\n- Column functions & expressions\n- Joins & broadcast joins\n- Window functions\n- Aggregations & groupBy\n- UDFs and pandas UDFs\n- Partitioning, repartition, coalesce\n- Caching / persistence\n- Shuffle, skew, and performance tips\n- Debugging & explain plan\n\nRun cells one-by-one. Each code cell is self-contained and prints results. Small datasets used for clarity.\n'

# %%
# Create lightweight SparkSession (if one doesn't exist)
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .appName("PySparkConceptsNotebook") \
    .config("spark.sql.shuffle.partitions", "8") \
    .getOrCreate()

print("Spark session ready; UI:", spark.sparkContext.uiWebUrl)
spark
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Spark session ready; UI: http://ip-10-0-137-151.us-west-2.compute.internal:40667
# ...
