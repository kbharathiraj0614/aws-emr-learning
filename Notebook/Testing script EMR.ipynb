# %%
from pyspark.sql import SparkSession
# Out:
# VBox()
# Starting Spark application
# <table>
# <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1</td><td>application_1764568572829_0002</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-0-129-190.us-west-2.compute.internal:20888/proxy/application_1764568572829_0002/" class="emr-proxy-link j-34P57CORAX76K application_1764568572829_0002" emr-resource="j-34P57CORAX76K
# " application-id="application_1764568572829_0002">Link</a></td><td><a target="_blank" href="http://ip-10-0-138-60.us-west-2.compute.internal:8042/node/containerlogs/container_1764568572829_0002_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# ...
